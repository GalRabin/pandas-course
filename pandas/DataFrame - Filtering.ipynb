# %% [markdown]
# # Filter a DataFrame based on a condition

# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
df["Senior Management"] = df["Senior Management"].astype(bool)
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-07-21 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-07-21 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-07-21 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
mask_male = df["Gender"] == "Male"
mask_male.head()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# Name: Gender, dtype: bool

# %%
df[df["Gender"] == "Male"]["Gender"].value_counts()
# Out:
# Male      424
# Female      0
# Name: Gender, dtype: int64

# %%
mask = df["Team"] == "Finance"
df[mask]["Team"].value_counts()
# Out:
# Finance    102
# Name: Team, dtype: int64

# %%
mask = df["Senior Management"] == True
df[mask]["Senior Management"].value_counts()
# Out:
# True    535
# Name: Senior Management, dtype: int64

# %%
mask = df["Team"] != "Marketing"
df[mask]["Team"].value_counts()
# Out:
# Client Services         106
# Finance                 102
# Business Development    101
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: Team, dtype: int64

# %%
mask = df["Salary"] > 110000
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-07-21 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-07-21 13:00:00  138705    9.340
# 5       Dennis    Male 1987-04-18 2022-07-21 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2022-07-21 06:51:00  139852    7.524
# 12     Brandon    Male 1980-12-01 2022-07-21 01:08:00  112807   17.492
# ..         ...     ...        ...                 ...     ...      ...
# 987     Gloria  Female 2014-12-08 2022-07-21 05:08:00  136709   10.331
# 991       Rose  Female 2002-08-25 2022-07-21 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-07-21 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2022-07-21 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2022-07-21 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# 3                 True               Finance
# 5                False                 Legal
# 9                 True  Business Development
# 12                True       Human Resources
# ..                 ...                   ...
# 987               True               Finance
# 991               True             Marketing
# 992               True               Finance
# 995              False          Distribution
# 999               True                 Sales
#
# [322 rows x 8 columns]

# %%
mask = df["Start Date"] <= "1985-01-01"
df[mask].shape
# Out:
# (133, 8)

# %% [markdown]
# ## Filtering with more than one condition

# %%
mask_gender_male = df["Gender"] == "Male"
mask_team_marketing = df["Team"] == "Marketing"
df[mask_gender_male & mask_team_marketing].shape
# Out:
# (41, 8)

# %%
mask1 = df["Senior Management"] == True
mask2 = df["Start Date"] < "1990-01-01"

df[mask1 | mask2].shape
# Out:
# (653, 8)

# %%
mask1 = df["First Name"] == "Robert"
mask2 = df["Team"] == "Client Services"
mask3 = df["Start Date"] > "2016-01-01"

df[(mask1 & mask2) | mask3].shape
# Out:
# (16, 8)

# %% [markdown]
# ## Isin method

# %%
mask1 = df["Team"] == "Legal"
mask2 = df["Team"] == "Sales"
mask3 = df["Team"] == "Product"

df[mask1 | mask2 | mask3].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male 1987-04-18 2022-07-21 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2022-07-21 16:20:00   65476   10.012
# 11      Julie  Female 1997-10-26 2022-07-21 15:19:00  102508   12.637
# 13       Gary    Male 2008-01-27 2022-07-21 23:40:00  109831    5.831
# 15    Lillian  Female 2016-06-05 2022-07-21 06:09:00   59414    1.256
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal
# 13              False    Sales
# 15              False  Product

# %%
mask = df["Team"].isin(values=["Legal", "Sales", "Product"])
df[mask].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male 1987-04-18 2022-07-21 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2022-07-21 16:20:00   65476   10.012
# 11      Julie  Female 1997-10-26 2022-07-21 15:19:00  102508   12.637
# 13       Gary    Male 2008-01-27 2022-07-21 23:40:00  109831    5.831
# 15    Lillian  Female 2016-06-05 2022-07-21 06:09:00   59414    1.256
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal
# 13              False    Sales
# 15              False  Product

# %% [markdown]
# ## Null checking

# %%
df[df["Team"].isnull()].shape
# Out:
# (43, 8)

# %%
df[df["Team"].notnull()].shape
# Out:
# (957, 8)

# %% [markdown]
# ## The between method

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-07-21 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-07-21 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-07-21 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-07-21 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-07-21 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df[df["Salary"].between(60000, 70000)].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2022-07-21 06:53:00   61933    4.170
# 6        Ruby  Female 1987-08-17 2022-07-21 16:20:00   65476   10.012
# 10     Louise  Female 1980-08-12 2022-07-21 09:01:00   63241   15.132
# 20       Lois     NaN 1995-04-22 2022-07-21 19:18:00   64714    4.934
# 41  Christine     NaN 2015-06-28 2022-07-21 01:08:00   66582   11.308
#
#     Senior Management                  Team
# 1                True                   NaN
# 6                True               Product
# 10               True                   NaN
# 20               True                 Legal
# 41               True  Business Development

# %%
df[df["Bonus %"].between(2.0, 5.0)].head()
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas   Male 1996-03-31 2022-07-21 06:53:00   61933    4.170
# 20       Lois    NaN 1995-04-22 2022-07-21 19:18:00   64714    4.934
# 40    Michael   Male 2008-10-10 2022-07-21 11:25:00   99283    2.665
# 49      Chris    NaN 1980-01-24 2022-07-21 12:13:00  113590    3.055
# 60      Paula    NaN 2005-11-23 2022-07-21 14:01:00   48866    4.271
#
#     Senior Management          Team
# 1                True           NaN
# 20               True         Legal
# 40               True  Distribution
# 49              False         Sales
# 60              False  Distribution

# %%
df[df["Start Date"].between("1991-01-01", "1992-02-02")].head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11 2022-07-21 18:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02 2022-07-21 01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27 2022-07-21 13:59:00   64088    6.155
# 116        NaN    Male 1991-06-22 2022-07-21 20:58:00   76189   18.988
# 148    Patrick     NaN 1991-07-14 2022-07-21 02:24:00  124488   14.837
#
#      Senior Management             Team
# 27               False            Legal
# 75                True  Human Resources
# 88                True            Legal
# 116               True            Legal
# 148               True            Sales

# %% [markdown]
# ## Find duplicate rows in DataFrame

# %%
df.sort_values(by="First Name", inplace=True)
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-07-21 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-07-21 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-07-21 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2022-07-21 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2022-07-21 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
df[df["First Name"].duplicated(keep=False)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-07-21 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-07-21 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-07-21 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-07-21 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2022-07-21 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-07-21 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-07-21 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-07-21 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-07-21 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-07-21 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution
# ..                 ...              ...
# 902               True     Distribution
# 925               True            Sales
# 946               True     Distribution
# 947               True        Marketing
# 951               True              NaN
#
# [991 rows x 8 columns]

# %%
df[df["First Name"].duplicated(keep="first")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron    Male 1994-01-29 2022-07-21 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-07-21 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-07-21 19:39:00   63126   18.424
# 141       Adam    Male 1990-12-24 2022-07-21 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2022-07-21 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-07-21 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-07-21 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-07-21 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-07-21 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-07-21 05:19:00  143638    9.662
#
#      Senior Management             Team
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 141               True          Product
# 302               True  Human Resources
# ..                 ...              ...
# 902               True     Distribution
# 925               True            Sales
# 946               True     Distribution
# 947               True        Marketing
# 951               True              NaN
#
# [799 rows x 8 columns]

# %%
df[~df["First Name"].duplicated(keep="last")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 937      Aaron     NaN 1986-01-22 2022-07-21 19:39:00   63126   18.424
# 538       Adam    Male 2010-10-08 2022-07-21 21:53:00   45181    3.491
# 610       Alan    Male 2012-02-17 2022-07-21 00:26:00   41453   10.084
# 372     Albert    Male 1997-02-01 2022-07-21 16:20:00   67827   19.717
# 693      Alice  Female 1995-10-16 2022-07-21 21:19:00   92799    2.782
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2022-07-21 13:44:00   65362    7.132
# 448      Wayne    Male 1992-01-30 2022-07-21 15:01:00   81183   17.066
# 820    William    Male 1993-11-18 2022-07-21 12:27:00   54058    5.182
# 652     Willie    Male 2009-12-05 2022-07-21 05:39:00  141932    1.017
# 951        NaN  Female 2010-09-14 2022-07-21 05:19:00  143638    9.662
#
#      Senior Management             Team
# 937              False  Client Services
# 538              False  Human Resources
# 610              False          Product
# 372               True      Engineering
# 693              False            Sales
# ..                 ...              ...
# 433               True            Legal
# 448              False  Client Services
# 820               True  Human Resources
# 652               True      Engineering
# 951               True              NaN
#
# [201 rows x 8 columns]

# %% [markdown]
# ## Drop duplicates

# %%
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-07-21 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-07-21 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-07-21 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2022-07-21 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2022-07-21 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates())
# Out:
# 1000

# %%
len(df.drop_duplicates(subset=["First Name"], keep="first"))
# Out:
# 201

# %%
len(df.drop_duplicates(subset=["First Name"], keep="last"))
# Out:
# 201

# %%
len(df.drop_duplicates(subset=["First Name"], keep=False))
# Out:
# 9

# %%
len(df.drop_duplicates(subset=["First Name", "Team"], keep="last"))
# Out:
# 769

# %% [markdown]
# ## Unique and nunique methods on Series

# %%
df["Gender"].unique()
# Out:
# ['Male', NaN, 'Female']
# Categories (2, object): ['Female', 'Male']

# %%
df["Team"].unique()
# Out:
# array(['Marketing', 'Client Services', 'Distribution', 'Product',
#        'Human Resources', 'Engineering', 'Finance',
#        'Business Development', 'Sales', nan, 'Legal'], dtype=object)

# %%
len(df["Team"].unique())
# Out:
# 11

# %%
# Does not include null values
df["Team"].nunique(dropna=False)
# Out:
# 11
